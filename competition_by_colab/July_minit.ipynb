# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from keras.utils import to_categorical
from tensorflow.examples.tutorials.mnist import input_data
import time
# Out:
# Using TensorFlow backend.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
data = pd.read_csv('/content/gdrive/My Drive/DeepLearning/train_july.csv')

# %%
train_y = data['label']
train_X = data.drop(['label'],axis=1)

# %%
train_X = np.array(train_X)
train_y = np.array(train_y).reshape(60000,1)
train_y = to_categorical(train_y)

# %%
x = tf.placeholder('float',[None,784])
y = tf.placeholder('float',[None,10])
x_image = tf.reshape(x,[-1,28,28,1])

# %%
#第一层
filter1 = tf.Variable(tf.truncated_normal([5,5,1,6]))
bias1 = tf.Variable(tf.truncated_normal([6]))
conv1 = tf.nn.conv2d(x_image,filter1,strides=[1,1,1,1],padding='SAME')
h_conv1 = tf.nn.sigmoid(conv1+bias1)
#第二层
maxPool2 = tf.nn.max_pool(h_conv1,ksize=[1,2,2,1],strides=[1,2,2,1],padding='SAME')
#第三层
filter2 = tf.Variable(tf.truncated_normal([5,5,6,16]))
bias2 = tf.Variable(tf.truncated_normal([16]))
conv2 = tf.nn.conv2d(maxPool2,filter2,strides=[1,1,1,1],padding='SAME')
h_conv2 = tf.nn.sigmoid(conv2+bias2)
#第四层
maxPool3 = tf.nn.max_pool(h_conv2,ksize=[1,2,2,1],strides=[1,2,2,1],padding='SAME')
#第五层
filter3 = tf.Variable(tf.truncated_normal([5,5,16,120]))
bias3 = tf.Variable(tf.truncated_normal([120]))
conv3 = tf.nn.conv2d(maxPool3,filter3,strides=[1,1,1,1],padding='SAME')
h_conv3 = tf.nn.sigmoid(conv3)
#第六层
W_fc1 = tf.Variable(tf.truncated_normal([7*7*120,80]))
bias_fc1 = tf.Variable(tf.truncated_normal([80]))
h_pool2_flat = tf.reshape(h_conv3,[-1,7*7*120])
h_fc1 = tf.nn.sigmoid(tf.matmul(h_pool2_flat,W_fc1)+bias_fc1)
#第七层
W_fc2 = tf.Variable(tf.truncated_normal([80,10]))
bias_fc2 = tf.Variable(tf.truncated_normal([10]))
y_conv = tf.nn.softmax(tf.matmul(h_fc1,W_fc2)+bias_fc2)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
cross_entropy = -tf.reduce_sum(y*tf.log(y_conv))
train_step = tf.train.GradientDescentOptimizer(0.001).minimize(cross_entropy)

# %%
sess = tf.InteractiveSession()
correct_prediction = tf.equal(tf.argmax(y_conv,1),tf.argmax(y,1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction,"float"))
sess.run(tf.global_variables_initializer())
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py:1702: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '

# %%
c = []
for j in range(150):
  for i in range(300):
      batch_xs = train_X[i*200:(i+1)*200,:]
      batch_xs = batch_xs/255
      batch_ys = train_y[i*200:(i+1)*200,:]
      train_step.run(feed_dict={x:batch_xs,y:batch_ys})
      if i %10 ==0:
          train_accuracy = accuracy.eval(feed_dict={x: batch_xs, y: batch_ys})
          c.append(train_accuracy)
          print("step %d, training accuracy %g"%(i,train_accuracy))
plt.show(c)
# Out:
# step 0, training accuracy 0.115
# step 10, training accuracy 0.155
# step 20, training accuracy 0.225
# step 30, training accuracy 0.36
# step 40, training accuracy 0.23
# step 50, training accuracy 0.33
# step 60, training accuracy 0.265
# step 70, training accuracy 0.22
# step 80, training accuracy 0.33
# step 90, training accuracy 0.5
# step 100, training accuracy 0.465
# step 110, training accuracy 0.44
# step 120, training accuracy 0.52
# step 130, training accuracy 0.5
# step 140, training accuracy 0.51
# step 150, training accuracy 0.49
# step 160, training accuracy 0.54
# step 170, training accuracy 0.56
# step 180, training accuracy 0.475
# step 190, training accuracy 0.535
# step 200, training accuracy 0.65
# step 210, training accuracy 0.575
# step 220, training accuracy 0.585
# step 230, training accuracy 0.645
# step 240, training accuracy 0.735
# step 250, training accuracy 0.65
# step 260, training accuracy 0.57
# step 270, training accuracy 0.665
# step 280, training accuracy 0.585
# step 290, training accuracy 0.79
# step 0, training accuracy 0.655
# step 10, training accuracy 0.795
# step 20, training accuracy 0.71
# step 30, training accuracy 0.805
# step 40, training accuracy 0.8
# step 50, training accuracy 0.78
# step 60, training accuracy 0.73
# step 70, training accuracy 0.78
# step 80, training accuracy 0.685
# step 90, training accuracy 0.8
# step 100, training accuracy 0.77
# step 110, training accuracy 0.81
# step 120, training accuracy 0.835
# step 130, training accuracy 0.805
# step 140, training accuracy 0.87
# step 150, training accuracy 0.755
# step 160, training accuracy 0.72
# step 170, training accuracy 0.81
# step 180, training accuracy 0.79
# step 190, training accuracy 0.805
# step 200, training accuracy 0.87
# step 210, training accuracy 0.755
# step 220, training accuracy 0.755
# step 230, training accuracy 0.83
# step 240, training accuracy 0.8
# step 250, training accuracy 0.785
# step 260, training accuracy 0.78
# step 270, training accuracy 0.855
# step 280, training accuracy 0.75
# step 290, training accuracy 0.935
# step 0, training accuracy 0.85
# step 10, training accuracy 0.855
# step 20, training accuracy 0.87
# step 30, training accuracy 0.91
# step 40, training accuracy 0.885
# step 50, training accuracy 0.86
# step 60, training accuracy 0.89
# step 70, training accuracy 0.845
# step 80, training accuracy 0.87
# step 90, training accuracy 0.87
# step 100, training accuracy 0.845
# step 110, training accuracy 0.875
# step 120, training accuracy 0.89
# step 130, training accuracy 0.9
# step 140, training accuracy 0.935
# step 150, training accuracy 0.825
# step 160, training accuracy 0.855
# step 170, training accuracy 0.9
# step 180, training accuracy 0.915
# step 190, training accuracy 0.875
# step 200, training accuracy 0.91
# step 210, training accuracy 0.875
# step 220, training accuracy 0.875
# step 230, training accuracy 0.89
# step 240, training accuracy 0.915
# step 250, training accuracy 0.815
# step 260, training accuracy 0.795
# step 270, training accuracy 0.835
# step 280, training accuracy 0.9
# step 290, training accuracy 0.945
# step 0, training accuracy 0.93
# step 10, training accuracy 0.94
# step 20, training accuracy 0.87
# step 30, training accuracy 0.93
# step 40, training accuracy 0.92
# step 50, training accuracy 0.91
# step 60, training accuracy 0.91
# step 70, training accuracy 0.9
# step 80, training accuracy 0.91
# step 90, training accuracy 0.925
# step 100, training accuracy 0.85
# step 110, training accuracy 0.94
# step 120, training accuracy 0.86
# step 130, training accuracy 0.935
# step 140, training accuracy 0.935
# step 150, training accuracy 0.77
# step 160, training accuracy 0.87
# step 170, training accuracy 0.915
# step 180, training accuracy 0.92
# step 190, training accuracy 0.92
# step 200, training accuracy 0.905
# step 210, training accuracy 0.88
# step 220, training accuracy 0.87
# step 230, training accuracy 0.925
# step 240, training accuracy 0.92
# step 250, training accuracy 0.865
# step 260, training accuracy 0.82
# step 270, training accuracy 0.9
# step 280, training accuracy 0.93
# step 290, training accuracy 0.965
# step 0, training accuracy 0.935
# step 10, training accuracy 0.955
# step 20, training accuracy 0.915
# step 30, training accuracy 0.96
# step 40, training accuracy 0.95
# step 50, training accuracy 0.915
# step 60, training accuracy 0.925
# step 70, training accuracy 0.92
# step 80, training accuracy 0.915
# step 90, training accuracy 0.92
# step 100, training accuracy 0.88
# step 110, training accuracy 0.93
# step 120, training accuracy 0.89
# step 130, training accuracy 0.95
# step 140, training accuracy 0.94
# step 150, training accuracy 0.9
# step 160, training accuracy 0.92
# step 170, training accuracy 0.94
# step 180, training accuracy 0.92
# step 190, training accuracy 0.94
# step 200, training accuracy 0.93
# step 210, training accuracy 0.89
# step 220, training accuracy 0.9
# step 230, training accuracy 0.915
# step 240, training accuracy 0.935
# step 250, training accuracy 0.895
# step 260, training accuracy 0.85
# step 270, training accuracy 0.91
# step 280, training accuracy 0.925
# step 290, training accuracy 0.95
# step 0, training accuracy 0.915
# step 10, training accuracy 0.945
# step 20, training accuracy 0.92
# step 30, training accuracy 0.96
# step 40, training accuracy 0.955
# step 50, training accuracy 0.925
# step 60, training accuracy 0.95
# step 70, training accuracy 0.935
# step 80, training accuracy 0.94
# step 90, training accuracy 0.93
# step 100, training accuracy 0.91
# step 110, training accuracy 0.925
# step 120, training accuracy 0.93
# step 130, training accuracy 0.96
# step 140, training accuracy 0.96
# step 150, training accuracy 0.88
# step 160, training accuracy 0.915
# step 170, training accuracy 0.96
# step 180, training accuracy 0.92
# step 190, training accuracy 0.955
# step 200, training accuracy 0.955
# step 210, training accuracy 0.9
# step 220, training accuracy 0.915
# step 230, training accuracy 0.955
# step 240, training accuracy 0.93
# step 250, training accuracy 0.91
# step 260, training accuracy 0.875
# step 270, training accuracy 0.935
# step 280, training accuracy 0.925
# step 290, training accuracy 0.96
# step 0, training accuracy 0.95
# step 10, training accuracy 0.96
# step 20, training accuracy 0.915
# step 30, training accuracy 0.96
# step 40, training accuracy 0.955
# step 50, training accuracy 0.935
# step 60, training accuracy 0.945
# step 70, training accuracy 0.94
# step 80, training accuracy 0.93
# step 90, training accuracy 0.94
# step 100, training accuracy 0.935
# step 110, training accuracy 0.95
# step 120, training accuracy 0.915
# step 130, training accuracy 0.97
# step 140, training accuracy 0.965
# step 150, training accuracy 0.895
# step 160, training accuracy 0.945
# step 170, training accuracy 0.96
# step 180, training accuracy 0.92
# step 190, training accuracy 0.945
# step 200, training accuracy 0.955
# step 210, training accuracy 0.92
# step 220, training accuracy 0.91
# step 230, training accuracy 0.945
# step 240, training accuracy 0.94
# step 250, training accuracy 0.935
# step 260, training accuracy 0.855
# step 270, training accuracy 0.92
# step 280, training accuracy 0.945
# step 290, training accuracy 0.97
# step 0, training accuracy 0.95
# step 10, training accuracy 0.965
# step 20, training accuracy 0.9
# step 30, training accuracy 0.96
# step 40, training accuracy 0.94
# step 50, training accuracy 0.93
# step 60, training accuracy 0.95
# step 70, training accuracy 0.94
# step 80, training accuracy 0.955
# step 90, training accuracy 0.945
# step 100, training accuracy 0.915
# step 110, training accuracy 0.95
# step 120, training accuracy 0.915
# step 130, training accuracy 0.98
# step 140, training accuracy 0.965
# step 150, training accuracy 0.91
# step 160, training accuracy 0.925
# step 170, training accuracy 0.97
# step 180, training accuracy 0.925
# step 190, training accuracy 0.95
# step 200, training accuracy 0.965
# step 210, training accuracy 0.925
# step 220, training accuracy 0.945
# step 230, training accuracy 0.95
# step 240, training accuracy 0.965
# step 250, training accuracy 0.945
# step 260, training accuracy 0.905
# step 270, training accuracy 0.94
# step 280, training accuracy 0.955
# step 290, training accuracy 0.975
# step 0, training accuracy 0.95
# step 10, training accuracy 0.94
# step 20, training accuracy 0.925
# step 30, training accuracy 0.965
# step 40, training accuracy 0.955
# step 50, training accuracy 0.95
# step 60, training accuracy 0.97
# step 70, training accuracy 0.94
# step 80, training accuracy 0.94
# step 90, training accuracy 0.96
# step 100, training accuracy 0.915
# step 110, training accuracy 0.96
# step 120, training accuracy 0.92
# step 130, training accuracy 0.98
# step 140, training accuracy 0.975
# step 150, training accuracy 0.94
# step 160, training accuracy 0.93
# step 170, training accuracy 0.985
# step 180, training accuracy 0.915
# step 190, training accuracy 0.945
# step 200, training accuracy 0.97
# step 210, training accuracy 0.95
# step 220, training accuracy 0.955
# step 230, training accuracy 0.94
# step 240, training accuracy 0.98
# step 250, training accuracy 0.94
# step 260, training accuracy 0.915
# step 270, training accuracy 0.965
# step 280, training accuracy 0.965
# step 290, training accuracy 0.975
# step 0, training accuracy 0.96
# step 10, training accuracy 0.96
# step 20, training accuracy 0.92
# step 30, training accuracy 0.975
# step 40, training accuracy 0.94
# step 50, training accuracy 0.945
# step 60, training accuracy 0.965
# step 70, training accuracy 0.945
# step 80, training accuracy 0.95
# step 90, training accuracy 0.955
# step 100, training accuracy 0.925
# step 110, training accuracy 0.975
# step 120, training accuracy 0.95
# step 130, training accuracy 0.97
# step 140, training accuracy 0.965
# step 150, training accuracy 0.93
# step 160, training accuracy 0.93
# step 170, training accuracy 0.985
# step 180, training accuracy 0.92
# step 190, training accuracy 0.96
# step 200, training accuracy 0.96
# step 210, training accuracy 0.93
# step 220, training accuracy 0.955
# step 230, training accuracy 0.94
# step 240, training accuracy 0.965
# step 250, training accuracy 0.935
# step 260, training accuracy 0.9
# step 270, training accuracy 0.955
# step 280, training accuracy 0.965
# step 290, training accuracy 0.98
# step 0, training accuracy 0.95
# step 10, training accuracy 0.96
# step 20, training accuracy 0.92
# step 30, training accuracy 0.98
# step 40, training accuracy 0.95
# step 50, training accuracy 0.935
# step 60, training accuracy 0.975
# step 70, training accuracy 0.95
# step 80, training accuracy 0.96
# step 90, training accuracy 0.965
# step 100, training accuracy 0.935
# step 110, training accuracy 0.97
# step 120, training accuracy 0.955
# step 130, training accuracy 0.975
# step 140, training accuracy 0.98
# step 150, training accuracy 0.945
# step 160, training accuracy 0.95
# step 170, training accuracy 0.98
# step 180, training accuracy 0.94
# step 190, training accuracy 0.97
# step 200, training accuracy 0.97
# step 210, training accuracy 0.945
# step 220, training accuracy 0.95
# step 230, training accuracy 0.945
# step 240, training accuracy 0.96
# step 250, training accuracy 0.915
# step 260, training accuracy 0.905
# step 270, training accuracy 0.945
# step 280, training accuracy 0.965
# step 290, training accuracy 0.975
# step 0, training accuracy 0.96
# step 10, training accuracy 0.965
# step 20, training accuracy 0.925
# step 30, training accuracy 0.99
# step 40, training accuracy 0.95
# step 50, training accuracy 0.94
# step 60, training accuracy 0.975
# step 70, training accuracy 0.96
# step 80, training accuracy 0.96
# step 90, training accuracy 0.955
# step 100, training accuracy 0.945
# step 110, training accuracy 0.95
# step 120, training accuracy 0.945
# step 130, training accuracy 0.98
# step 140, training accuracy 0.98
# step 150, training accuracy 0.93
# step 160, training accuracy 0.965
# step 170, training accuracy 0.985
# step 180, training accuracy 0.94
# step 190, training accuracy 0.975
# step 200, training accuracy 0.97
# step 210, training accuracy 0.93
# step 220, training accuracy 0.965
# step 230, training accuracy 0.955
# step 240, training accuracy 0.98
# step 250, training accuracy 0.955
# step 260, training accuracy 0.925
# step 270, training accuracy 0.97
# step 280, training accuracy 0.985
# step 290, training accuracy 0.975
# step 0, training accuracy 0.95
# step 10, training accuracy 0.97
# step 20, training accuracy 0.935
# step 30, training accuracy 0.99
# step 40, training accuracy 0.96
# step 50, training accuracy 0.935
# step 60, training accuracy 0.955
# step 70, training accuracy 0.96
# step 80, training accuracy 0.96
# step 90, training accuracy 0.955
# step 100, training accuracy 0.98
# step 110, training accuracy 0.97
# step 120, training accuracy 0.96
# step 130, training accuracy 0.98
# step 140, training accuracy 0.975
# step 150, training accuracy 0.955
# step 160, training accuracy 0.95
# step 170, training accuracy 0.99
# step 180, training accuracy 0.935
# step 190, training accuracy 0.975
# step 200, training accuracy 0.985
# step 210, training accuracy 0.95
# step 220, training accuracy 0.965
# step 230, training accuracy 0.94
# step 240, training accuracy 0.975
# step 250, training accuracy 0.975
# step 260, training accuracy 0.88
# step 270, training accuracy 0.965
# step 280, training accuracy 0.97
# step 290, training accuracy 0.985
# step 0, training accuracy 0.96
# step 10, training accuracy 0.975
# step 20, training accuracy 0.94
# step 30, training accuracy 0.99
# step 40, training accuracy 0.98
# step 50, training accuracy 0.94
# step 60, training accuracy 0.97
# step 70, training accuracy 0.96
# step 80, training accuracy 0.96
# step 90, training accuracy 0.95
# step 100, training accuracy 0.97
# step 110, training accuracy 0.975
# step 120, training accuracy 0.965
# step 130, training accuracy 0.99
# step 140, training accuracy 0.985
# step 150, training accuracy 0.97
# step 160, training accuracy 0.96
# step 170, training accuracy 0.98
# step 180, training accuracy 0.94
# step 190, training accuracy 0.97
# step 200, training accuracy 0.98
# step 210, training accuracy 0.955
# step 220, training accuracy 0.95
# step 230, training accuracy 0.945
# step 240, training accuracy 0.965
# step 250, training accuracy 0.97
# step 260, training accuracy 0.93
# step 270, training accuracy 0.96
# step 280, training accuracy 0.98
# step 290, training accuracy 0.985
# step 0, training accuracy 0.955
# step 10, training accuracy 0.975
# step 20, training accuracy 0.935
# step 30, training accuracy 0.985
# step 40, training accuracy 0.97
# step 50, training accuracy 0.955
# step 60, training accuracy 0.99
# step 70, training accuracy 0.98
# step 80, training accuracy 0.965
# step 90, training accuracy 0.97
# step 100, training accuracy 0.96
# step 110, training accuracy 0.97
# step 120, training accuracy 0.98
# step 130, training accuracy 0.99
# step 140, training accuracy 0.985
# step 150, training accuracy 0.97
# step 160, training accuracy 0.96
# step 170, training accuracy 0.99
# step 180, training accuracy 0.95
# step 190, training accuracy 0.975
# step 200, training accuracy 0.985
# step 210, training accuracy 0.97
# step 220, training accuracy 0.97
# step 230, training accuracy 0.94
# step 240, training accuracy 0.985
# step 250, training accuracy 0.96
# step 260, training accuracy 0.925
# step 270, training accuracy 0.955
# step 280, training accuracy 0.995
# step 290, training accuracy 0.985
# step 0, training accuracy 0.97
# step 10, training accuracy 0.975
# step 20, training accuracy 0.945
# step 30, training accuracy 0.98
# step 40, training accuracy 0.975
# step 50, training accuracy 0.96
# step 60, training accuracy 0.985
# step 70, training accuracy 0.975
# step 80, training accuracy 0.975
# step 90, training accuracy 0.96
# step 100, training accuracy 0.97
# step 110, training accuracy 0.975
# step 120, training accuracy 0.96
# step 130, training accuracy 0.98
# step 140, training accuracy 0.985
# step 150, training accuracy 0.965
# step 160, training accuracy 0.935
# step 170, training accuracy 0.985
# step 180, training accuracy 0.94
# step 190, training accuracy 0.975
# step 200, training accuracy 0.99
# step 210, training accuracy 0.975
# step 220, training accuracy 0.975
# step 230, training accuracy 0.955
# step 240, training accuracy 0.98
# step 250, training accuracy 0.975
# step 260, training accuracy 0.915
# step 270, training accuracy 0.96
# step 280, training accuracy 0.995
# step 290, training accuracy 0.985
# step 0, training accuracy 0.965
# step 10, training accuracy 0.975
# step 20, training accuracy 0.965
# step 30, training accuracy 0.98
# step 40, training accuracy 0.965
# step 50, training accuracy 0.95
# step 60, training accuracy 0.98
# step 70, training accuracy 0.965
# step 80, training accuracy 0.975
# step 90, training accuracy 0.97
# step 100, training accuracy 0.96
# step 110, training accuracy 0.96
# step 120, training accuracy 0.95
# step 130, training accuracy 0.995
# step 140, training accuracy 0.98
# step 150, training accuracy 0.975
# step 160, training accuracy 0.96
# step 170, training accuracy 0.985
# step 180, training accuracy 0.94
# step 190, training accuracy 0.955
# step 200, training accuracy 0.99
# step 210, training accuracy 0.965
# step 220, training accuracy 0.965
# step 230, training accuracy 0.955
# step 240, training accuracy 0.985
# step 250, training accuracy 0.965
# step 260, training accuracy 0.93
# step 270, training accuracy 0.955
# step 280, training accuracy 0.99
# step 290, training accuracy 0.99
# step 0, training accuracy 0.97
# step 10, training accuracy 0.975
# step 20, training accuracy 0.95
# step 30, training accuracy 0.98
# step 40, training accuracy 0.965
# step 50, training accuracy 0.96
# step 60, training accuracy 0.975
# step 70, training accuracy 0.965
# step 80, training accuracy 0.965
# step 90, training accuracy 0.96
# step 100, training accuracy 0.96
# step 110, training accuracy 0.975
# step 120, training accuracy 0.965
# step 130, training accuracy 0.985
# step 140, training accuracy 0.985
# step 150, training accuracy 0.965
# step 160, training accuracy 0.97
# step 170, training accuracy 0.985
# step 180, training accuracy 0.94
# step 190, training accuracy 0.975
# step 200, training accuracy 0.985
# step 210, training accuracy 0.96
# step 220, training accuracy 0.965
# step 230, training accuracy 0.955
# step 240, training accuracy 0.99
# step 250, training accuracy 0.985
# step 260, training accuracy 0.925
# step 270, training accuracy 0.97
# step 280, training accuracy 0.99
# step 290, training accuracy 0.975
# step 0, training accuracy 0.97
# step 10, training accuracy 0.97
# step 20, training accuracy 0.98
# step 30, training accuracy 0.985
# step 40, training accuracy 0.985
# step 50, training accuracy 0.96
# step 60, training accuracy 0.985
# step 70, training accuracy 0.97
# step 80, training accuracy 0.975
# step 90, training accuracy 0.97
# step 100, training accuracy 0.97
# step 110, training accuracy 0.99
# step 120, training accuracy 0.975
# step 130, training accuracy 0.985
# step 140, training accuracy 0.985
# step 150, training accuracy 0.98
# step 160, training accuracy 0.98
# step 170, training accuracy 0.99
# step 180, training accuracy 0.95
# step 190, training accuracy 0.95
# step 200, training accuracy 0.98
# step 210, training accuracy 0.97
# step 220, training accuracy 0.975
# step 230, training accuracy 0.955
# step 240, training accuracy 0.99
# step 250, training accuracy 0.985
# step 260, training accuracy 0.93
# step 270, training accuracy 0.975
# step 280, training accuracy 0.99
# step 290, training accuracy 0.985
# step 0, training accuracy 0.96
# step 10, training accuracy 0.97
# step 20, training accuracy 0.975
# step 30, training accuracy 0.985
# step 40, training accuracy 0.99
# step 50, training accuracy 0.955
# step 60, training accuracy 0.98
# step 70, training accuracy 0.985
# step 80, training accuracy 0.975
# step 90, training accuracy 0.975
# step 100, training accuracy 0.97
# step 110, training accuracy 0.98
# step 120, training accuracy 0.975
# step 130, training accuracy 0.985
# step 140, training accuracy 0.99
# step 150, training accuracy 0.985
# step 160, training accuracy 0.97
# step 170, training accuracy 0.99
# step 180, training accuracy 0.95
# step 190, training accuracy 0.99
# step 200, training accuracy 0.99
# step 210, training accuracy 0.98
# step 220, training accuracy 0.975
# step 230, training accuracy 0.95
# step 240, training accuracy 0.985
# step 250, training accuracy 0.975
# step 260, training accuracy 0.94
# step 270, training accuracy 0.975
# step 280, training accuracy 0.995
# step 290, training accuracy 0.99
# step 0, training accuracy 0.97
# step 10, training accuracy 0.97
# step 20, training accuracy 0.96
# step 30, training accuracy 0.985
# step 40, training accuracy 0.985
# step 50, training accuracy 0.95
# step 60, training accuracy 0.98
# step 70, training accuracy 0.98
# step 80, training accuracy 0.975
# step 90, training accuracy 0.975
# step 100, training accuracy 0.97
# step 110, training accuracy 0.985
# step 120, training accuracy 0.975
# step 130, training accuracy 0.99
# step 140, training accuracy 0.99
# step 150, training accuracy 0.97
# step 160, training accuracy 0.98
# step 170, training accuracy 0.99
# step 180, training accuracy 0.95
# step 190, training accuracy 0.965
# step 200, training accuracy 0.995
# step 210, training accuracy 0.965
# step 220, training accuracy 0.975
# step 230, training accuracy 0.955
# step 240, training accuracy 0.99
# step 250, training accuracy 0.975
# step 260, training accuracy 0.93
# step 270, training accuracy 0.975
# step 280, training accuracy 1
# step 290, training accuracy 0.98
# step 0, training accuracy 0.97
# step 10, training accuracy 0.99
# step 20, training accuracy 0.965
# step 30, training accuracy 0.99
# step 40, training accuracy 0.965
# step 50, training accuracy 0.96
# step 60, training accuracy 0.975
# step 70, training accuracy 0.975
# step 80, training accuracy 0.98
# step 90, training accuracy 0.98
# step 100, training accuracy 0.98
# step 110, training accuracy 0.985
# step 120, training accuracy 0.975
# step 130, training accuracy 0.995
# step 140, training accuracy 0.975
# step 150, training accuracy 0.985
# step 160, training accuracy 0.97
# step 170, training accuracy 0.985
# step 180, training accuracy 0.96
# step 190, training accuracy 0.98
# step 200, training accuracy 0.985
# step 210, training accuracy 0.96
# step 220, training accuracy 0.97
# step 230, training accuracy 0.96
# step 240, training accuracy 0.98
# step 250, training accuracy 0.99
# step 260, training accuracy 0.95
# step 270, training accuracy 0.98
# step 280, training accuracy 0.985
# step 290, training accuracy 0.99
# step 0, training accuracy 0.965
# step 10, training accuracy 0.99
# step 20, training accuracy 0.98
# step 30, training accuracy 0.985
# step 40, training accuracy 0.995
# step 50, training accuracy 0.955
# step 60, training accuracy 0.98
# step 70, training accuracy 0.985
# step 80, training accuracy 0.985
# step 90, training accuracy 0.97
# step 100, training accuracy 0.975
# step 110, training accuracy 0.98
# step 120, training accuracy 0.97
# step 130, training accuracy 0.995
# step 140, training accuracy 0.995
# step 150, training accuracy 0.99
# step 160, training accuracy 0.98
# step 170, training accuracy 0.99
# step 180, training accuracy 0.955
# step 190, training accuracy 0.975
# step 200, training accuracy 0.99
# step 210, training accuracy 0.975
# step 220, training accuracy 0.975
# step 230, training accuracy 0.96
# step 240, training accuracy 0.99
# step 250, training accuracy 0.98
# step 260, training accuracy 0.955
# step 270, training accuracy 0.975
# step 280, training accuracy 0.995
# step 290, training accuracy 0.99
# step 0, training accuracy 0.975
# step 10, training accuracy 0.985
# step 20, training accuracy 0.97
# step 30, training accuracy 0.985
# step 40, training accuracy 1
# step 50, training accuracy 0.95
# step 60, training accuracy 0.975
# step 70, training accuracy 0.99
# step 80, training accuracy 0.985
# step 90, training accuracy 0.98
# step 100, training accuracy 0.975
# step 110, training accuracy 0.98
# step 120, training accuracy 0.965
# step 130, training accuracy 0.985
# step 140, training accuracy 0.99
# step 150, training accuracy 0.975
# step 160, training accuracy 0.97
# step 170, training accuracy 0.99
# step 180, training accuracy 0.96
# step 190, training accuracy 0.975
# step 200, training accuracy 0.99
# step 210, training accuracy 0.985
# step 220, training accuracy 0.97
# step 230, training accuracy 0.98
# step 240, training accuracy 0.99
# step 250, training accuracy 0.99
# step 260, training accuracy 0.95
# step 270, training accuracy 0.975
# step 280, training accuracy 1
# step 290, training accuracy 0.985
# step 0, training accuracy 0.98
# step 10, training accuracy 0.995
# step 20, training accuracy 0.985
# step 30, training accuracy 0.99
# step 40, training accuracy 0.98
# step 50, training accuracy 0.965
# step 60, training accuracy 0.98
# step 70, training accuracy 0.985
# step 80, training accuracy 0.975
# step 90, training accuracy 0.985
# step 100, training accuracy 0.98
# step 110, training accuracy 0.97
# step 120, training accuracy 0.96
# step 130, training accuracy 0.99
# step 140, training accuracy 0.99
# step 150, training accuracy 0.985
# step 160, training accuracy 0.97
# step 170, training accuracy 0.985
# step 180, training accuracy 0.97
# step 190, training accuracy 0.99
# step 200, training accuracy 0.99
# step 210, training accuracy 0.965
# step 220, training accuracy 0.985
# step 230, training accuracy 0.965
# step 240, training accuracy 0.985
# step 250, training accuracy 0.97
# step 260, training accuracy 0.945
# step 270, training accuracy 0.975
# step 280, training accuracy 0.995
# step 290, training accuracy 0.985
# step 0, training accuracy 0.975
# step 10, training accuracy 0.99
# step 20, training accuracy 0.98
# step 30, training accuracy 0.99
# step 40, training accuracy 0.99
# step 50, training accuracy 0.955
# step 60, training accuracy 0.98
# step 70, training accuracy 0.99
# step 80, training accuracy 0.975
# step 90, training accuracy 0.985
# step 100, training accuracy 0.97
# step 110, training accuracy 0.995
# step 120, training accuracy 0.975
# step 130, training accuracy 1
# step 140, training accuracy 0.995
# step 150, training accuracy 0.985
# step 160, training accuracy 0.97
# step 170, training accuracy 0.985
# step 180, training accuracy 0.965
# step 190, training accuracy 0.98
# step 200, training accuracy 0.985
# step 210, training accuracy 0.975
# step 220, training accuracy 0.975
# step 230, training accuracy 0.965
# step 240, training accuracy 0.99
# step 250, training accuracy 0.985
# step 260, training accuracy 0.955
# step 270, training accuracy 0.965
# step 280, training accuracy 0.995
# step 290, training accuracy 0.98
# step 0, training accuracy 0.985
# step 10, training accuracy 0.99
# step 20, training accuracy 0.98
# step 30, training accuracy 0.99
# step 40, training accuracy 0.99
# step 50, training accuracy 0.96
# step 60, training accuracy 0.995
# step 70, training accuracy 0.99
# step 80, training accuracy 0.98
# step 90, training accuracy 0.975
# step 100, training accuracy 0.975
# step 110, training accuracy 0.98
# step 120, training accuracy 0.975
# step 130, training accuracy 1
# step 140, training accuracy 0.985
# step 150, training accuracy 0.99
# step 160, training accuracy 0.97
# step 170, training accuracy 0.985
# step 180, training accuracy 0.965
# step 190, training accuracy 0.985
# step 200, training accuracy 0.99
# step 210, training accuracy 0.975
# step 220, training accuracy 0.97
# step 230, training accuracy 0.965
# step 240, training accuracy 0.985
# step 250, training accuracy 0.985
# step 260, training accuracy 0.955
# step 270, training accuracy 0.98
# step 280, training accuracy 0.99
# step 290, training accuracy 0.98
# step 0, training accuracy 0.98
# step 10, training accuracy 0.995
# step 20, training accuracy 0.975
# step 30, training accuracy 0.99
# step 40, training accuracy 0.995
# step 50, training accuracy 0.95
# step 60, training accuracy 0.99
# step 70, training accuracy 0.99
# step 80, training accuracy 0.985
# step 90, training accuracy 0.99
# step 100, training accuracy 0.98
# step 110, training accuracy 0.965
# step 120, training accuracy 0.985
# step 130, training accuracy 1
# step 140, training accuracy 0.995
# step 150, training accuracy 0.98
# step 160, training accuracy 0.975
# step 170, training accuracy 0.99
# step 180, training accuracy 0.96
# step 190, training accuracy 0.985
# step 200, training accuracy 0.995
# step 210, training accuracy 0.975
# step 220, training accuracy 0.99
# step 230, training accuracy 0.96
# step 240, training accuracy 0.985
# step 250, training accuracy 0.995
# step 260, training accuracy 0.93
# step 270, training accuracy 0.975
# step 280, training accuracy 1
# step 290, training accuracy 0.99
# step 0, training accuracy 0.975
# step 10, training accuracy 1
# step 20, training accuracy 0.98
# step 30, training accuracy 0.99
# step 40, training accuracy 0.985
# step 50, training accuracy 0.95
# step 60, training accuracy 0.99
# step 70, training accuracy 0.99
# step 80, training accuracy 0.99
# step 90, training accuracy 0.98
# step 100, training accuracy 0.975
# step 110, training accuracy 0.97
# step 120, training accuracy 0.985
# step 130, training accuracy 0.995
# step 140, training accuracy 0.99
# step 150, training accuracy 0.99
# step 160, training accuracy 0.975
# step 170, training accuracy 0.99
# step 180, training accuracy 0.955
# step 190, training accuracy 0.99
# step 200, training accuracy 0.99
# step 210, training accuracy 0.97
# step 220, training accuracy 0.98
# step 230, training accuracy 0.965
# step 240, training accuracy 0.995
# step 250, training accuracy 0.99
# step 260, training accuracy 0.96
# step 270, training accuracy 0.97
# step 280, training accuracy 1
# step 290, training accuracy 0.99
# step 0, training accuracy 0.98
# step 10, training accuracy 0.995
# step 20, training accuracy 0.99
# step 30, training accuracy 0.99
# step 40, training accuracy 0.99
# step 50, training accuracy 0.94
# step 60, training accuracy 0.99
# step 70, training accuracy 0.99
# step 80, training accuracy 0.98
# step 90, training accuracy 0.975
# step 100, training accuracy 0.975
# step 110, training accuracy 0.98
# step 120, training accuracy 0.99
# step 130, training accuracy 0.995
# step 140, training accuracy 0.985
# step 150, training accuracy 0.985
# step 160, training accuracy 0.96
# step 170, training accuracy 0.99
# step 180, training accuracy 0.945
# step 190, training accuracy 0.985
# step 200, training accuracy 0.995
# step 210, training accuracy 0.965
# step 220, training accuracy 0.975
# step 230, training accuracy 0.975
# step 240, training accuracy 0.98
# step 250, training accuracy 0.985
# step 260, training accuracy 0.955
# step 270, training accuracy 0.965
# step 280, training accuracy 0.995
# step 290, training accuracy 0.98
# step 0, training accuracy 0.975
# step 10, training accuracy 0.995
# step 20, training accuracy 0.985
# step 30, training accuracy 0.99
# step 40, training accuracy 0.99
# step 50, training accuracy 0.965
# step 60, training accuracy 0.985
# step 70, training accuracy 0.99
# step 80, training accuracy 0.975
# step 90, training accuracy 0.98
# step 100, training accuracy 0.97
# step 110, training accuracy 0.99
# step 120, training accuracy 0.985
# step 130, training accuracy 1
# step 140, training accuracy 0.99
# step 150, training accuracy 0.99
# step 160, training accuracy 0.98
# step 170, training accuracy 0.985
# step 180, training accuracy 0.965
# step 190, training accuracy 0.985
# step 200, training accuracy 0.99
# step 210, training accuracy 0.975
# step 220, training accuracy 0.985
# step 230, training accuracy 0.965
# step 240, training accuracy 0.995
# step 250, training accuracy 0.99
# step 260, training accuracy 0.96
# step 270, training accuracy 0.97
# step 280, training accuracy 1
# step 290, training accuracy 0.98
# step 0, training accuracy 0.975
# step 10, training accuracy 0.995
# step 20, training accuracy 0.99
# step 30, training accuracy 0.99
# step 40, training accuracy 0.99
# step 50, training accuracy 0.965
# step 60, training accuracy 1
# step 70, training accuracy 0.995
# step 80, training accuracy 0.99
# step 90, training accuracy 0.99
# step 100, training accuracy 0.99
# step 110, training accuracy 0.985
# step 120, training accuracy 0.98
# step 130, training accuracy 0.995
# step 140, training accuracy 0.985
# step 150, training accuracy 0.985
# step 160, training accuracy 0.97
# step 170, training accuracy 0.99
# step 180, training accuracy 0.96
# step 190, training accuracy 0.985
# step 200, training accuracy 0.995
# step 210, training accuracy 0.97
# step 220, training accuracy 0.98
# step 230, training accuracy 0.97
# step 240, training accuracy 0.99
# step 250, training accuracy 0.995
# step 260, training accuracy 0.975
# step 270, training accuracy 0.975
# step 280, training accuracy 0.985
# step 290, training accuracy 0.985
# step 0, training accuracy 0.98
# step 10, training accuracy 0.995
# step 20, training accuracy 0.985
# step 30, training accuracy 0.985
# step 40, training accuracy 0.995
# step 50, training accuracy 0.975
# step 60, training accuracy 0.99
# step 70, training accuracy 0.985
# step 80, training accuracy 0.99
# step 90, training accuracy 0.985
# step 100, training accuracy 0.975
# step 110, training accuracy 0.985
# step 120, training accuracy 0.99
# step 130, training accuracy 1
# step 140, training accuracy 1
# step 150, training accuracy 0.985
# step 160, training accuracy 0.98
# step 170, training accuracy 0.99
# step 180, training accuracy 0.96
# step 190, training accuracy 0.99
# step 200, training accuracy 0.99
# step 210, training accuracy 0.98
# step 220, training accuracy 0.98
# step 230, training accuracy 0.96
# step 240, training accuracy 0.995
# step 250, training accuracy 0.98
# step 260, training accuracy 0.955
# step 270, training accuracy 0.98
# step 280, training accuracy 0.995
# step 290, training accuracy 0.99
# step 0, training accuracy 0.985
# step 10, training accuracy 0.99
# step 20, training accuracy 0.985
# step 30, training accuracy 0.98
# step 40, training accuracy 0.99
# step 50, training accuracy 0.965
# step 60, training accuracy 1
# step 70, training accuracy 0.99
# step 80, training accuracy 0.995
# step 90, training accuracy 0.985
# step 100, training accuracy 0.975
# step 110, training accuracy 0.98
# step 120, training accuracy 0.99
# step 130, training accuracy 0.995
# step 140, training accuracy 0.995
# step 150, training accuracy 0.98
# step 160, training accuracy 0.985
# step 170, training accuracy 0.99
# step 180, training accuracy 0.97
# step 190, training accuracy 0.985
# step 200, training accuracy 0.99
# step 210, training accuracy 0.98
# step 220, training accuracy 0.98
# step 230, training accuracy 0.965
# step 240, training accuracy 0.995
# step 250, training accuracy 0.99
# step 260, training accuracy 0.96
# step 270, training accuracy 0.98
# step 280, training accuracy 1
# step 290, training accuracy 0.985
# step 0, training accuracy 0.97
# step 10, training accuracy 0.995
# step 20, training accuracy 0.98
# step 30, training accuracy 0.985
# step 40, training accuracy 0.995
# step 50, training accuracy 0.965
# step 60, training accuracy 0.99
# step 70, training accuracy 0.99
# step 80, training accuracy 0.985
# step 90, training accuracy 0.97
# step 100, training accuracy 0.98
# step 110, training accuracy 0.985
# step 120, training accuracy 0.995
# step 130, training accuracy 1
# step 140, training accuracy 0.99
# step 150, training accuracy 0.955
# step 160, training accuracy 0.97
# step 170, training accuracy 0.99
# step 180, training accuracy 0.97
# step 190, training accuracy 0.985
# step 200, training accuracy 0.99
# step 210, training accuracy 0.975
# step 220, training accuracy 0.98
# step 230, training accuracy 0.965
# step 240, training accuracy 0.995
# step 250, training accuracy 0.995
# step 260, training accuracy 0.965
# step 270, training accuracy 0.975
# step 280, training accuracy 1
# step 290, training accuracy 0.99
# step 0, training accuracy 0.98
# step 10, training accuracy 0.99
# step 20, training accuracy 0.985
# step 30, training accuracy 0.985
# step 40, training accuracy 0.99
# step 50, training accuracy 0.96
# step 60, training accuracy 1
# step 70, training accuracy 0.99
# step 80, training accuracy 0.98
# step 90, training accuracy 0.995
# step 100, training accuracy 0.98
# step 110, training accuracy 0.985
# step 120, training accuracy 0.995
# step 130, training accuracy 1
# step 140, training accuracy 0.99
# step 150, training accuracy 0.96
# step 160, training accuracy 0.98
# step 170, training accuracy 0.99
# step 180, training accuracy 0.965
# step 190, training accuracy 0.99
# step 200, training accuracy 0.99
# step 210, training accuracy 0.985
# step 220, training accuracy 0.985
# step 230, training accuracy 0.965
# step 240, training accuracy 0.995
# step 250, training accuracy 0.995
# step 260, training accuracy 0.965
# step 270, training accuracy 0.975
# step 280, training accuracy 1
# step 290, training accuracy 0.99
# step 0, training accuracy 0.99
# step 10, training accuracy 0.995
# step 20, training accuracy 0.99
# step 30, training accuracy 0.985
# step 40, training accuracy 0.995
# step 50, training accuracy 0.975
# step 60, training accuracy 0.995
# step 70, training accuracy 0.99
# step 80, training accuracy 0.995
# step 90, training accuracy 0.985
# step 100, training accuracy 0.975
# step 110, training accuracy 0.99
# step 120, training accuracy 0.995
# step 130, training accuracy 0.995
# step 140, training accuracy 0.99
# step 150, training accuracy 0.985
# step 160, training accuracy 0.98
# step 170, training accuracy 0.99
# step 180, training accuracy 0.975
# step 190, training accuracy 0.99
# step 200, training accuracy 0.995
# step 210, training accuracy 0.98
# step 220, training accuracy 0.975
# step 230, training accuracy 0.97
# step 240, training accuracy 0.995
# step 250, training accuracy 0.99
# step 260, training accuracy 0.965
# step 270, training accuracy 0.985
# step 280, training accuracy 0.995
# step 290, training accuracy 0.99
# step 0, training accuracy 0.985
# step 10, training accuracy 0.995
# step 20, training accuracy 0.99
# step 30, training accuracy 0.99
# step 40, training accuracy 0.995
# step 50, training accuracy 0.96
# step 60, training accuracy 0.985
# step 70, training accuracy 0.995
# step 80, training accuracy 0.99
# step 90, training accuracy 0.98
# step 100, training accuracy 0.97
# step 110, training accuracy 0.98
# step 120, training accuracy 0.995
# step 130, training accuracy 1
# step 140, training accuracy 0.99
# step 150, training accuracy 0.98
# step 160, training accuracy 0.98
# step 170, training accuracy 0.99
# step 180, training accuracy 0.96
# step 190, training accuracy 0.985
# step 200, training accuracy 1
# step 210, training accuracy 0.965
# step 220, training accuracy 0.985
# step 230, training accuracy 0.97
# step 240, training accuracy 0.995
# step 250, training accuracy 0.995
# step 260, training accuracy 0.955
# step 270, training accuracy 0.975
# step 280, training accuracy 1
# step 290, training accuracy 0.99
# step 0, training accuracy 0.98
# step 10, training accuracy 0.99
# step 20, training accuracy 0.995
# step 30, training accuracy 0.98
# step 40, training accuracy 0.995
# step 50, training accuracy 0.97
# step 60, training accuracy 0.99
# step 70, training accuracy 0.99
# step 80, training accuracy 0.995
# step 90, training accuracy 0.985
# step 100, training accuracy 0.98
# step 110, training accuracy 0.995
# step 120, training accuracy 0.995
# step 130, training accuracy 0.995
# step 140, training accuracy 0.99
# step 150, training accuracy 0.975
# step 160, training accuracy 0.97
# step 170, training accuracy 0.99
# step 180, training accuracy 0.965
# step 190, training accuracy 0.985
# step 200, training accuracy 0.995
# step 210, training accuracy 0.98
# step 220, training accuracy 0.99
# step 230, training accuracy 0.97
# step 240, training accuracy 0.99
# step 250, training accuracy 0.995
# step 260, training accuracy 0.96
# step 270, training accuracy 0.985
# step 280, training accuracy 1
# step 290, training accuracy 0.985
# step 0, training accuracy 0.98
# step 10, training accuracy 0.995
# step 20, training accuracy 0.985
# step 30, training accuracy 0.99
# step 40, training accuracy 0.995
# step 50, training accuracy 0.97
# step 60, training accuracy 1
# step 70, training accuracy 0.995
# step 80, training accuracy 0.99
# step 90, training accuracy 0.99
# step 100, training accuracy 0.99
# step 110, training accuracy 0.98
# step 120, training accuracy 0.995
# step 130, training accuracy 0.995
# step 140, training accuracy 0.99
# step 150, training accuracy 0.985
# step 160, training accuracy 0.985
# step 170, training accuracy 0.99
# step 180, training accuracy 0.97
# step 190, training accuracy 0.985
# step 200, training accuracy 0.995
# step 210, training accuracy 0.98
# step 220, training accuracy 0.99
# step 230, training accuracy 0.975
# step 240, training accuracy 0.995
# step 250, training accuracy 0.99
# step 260, training accuracy 0.96
# step 270, training accuracy 0.99
# step 280, training accuracy 1
# step 290, training accuracy 0.99
# step 0, training accuracy 0.99
# step 10, training accuracy 0.995
# step 20, training accuracy 0.995
# step 30, training accuracy 0.99
# step 40, training accuracy 0.995
# step 50, training accuracy 0.97
# step 60, training accuracy 0.995
# step 70, training accuracy 0.99
# step 80, training accuracy 0.985
# step 90, training accuracy 0.99
# step 100, training accuracy 0.98
# step 110, training accuracy 0.98
# step 120, training accuracy 0.995
# step 130, training accuracy 0.995
# step 140, training accuracy 0.99
# step 150, training accuracy 0.99
# step 160, training accuracy 0.98
# step 170, training accuracy 0.99
# step 180, training accuracy 0.96
# step 190, training accuracy 0.995
# step 200, training accuracy 1
# step 210, training accuracy 0.98
# step 220, training accuracy 0.98
# step 230, training accuracy 0.97
# step 240, training accuracy 0.99
# step 250, training accuracy 0.995
# step 260, training accuracy 0.965
# step 270, training accuracy 0.97
# step 280, training accuracy 0.995
# step 290, training accuracy 0.985
# step 0, training accuracy 0.985
# step 10, training accuracy 0.995
# step 20, training accuracy 0.98
# step 30, training accuracy 0.99
# step 40, training accuracy 0.995
# step 50, training accuracy 0.98
# step 60, training accuracy 0.98
# step 70, training accuracy 0.995
# step 80, training accuracy 0.985
# step 90, training accuracy 0.985
# step 100, training accuracy 0.975
# step 110, training accuracy 0.985
# step 120, training accuracy 0.995
# step 130, training accuracy 0.99
# step 140, training accuracy 0.995
# step 150, training accuracy 0.985
# step 160, training accuracy 0.985
# step 170, training accuracy 0.99
# step 180, training accuracy 0.965
# step 190, training accuracy 0.98
# step 200, training accuracy 0.995
# step 210, training accuracy 0.985
# step 220, training accuracy 0.985
# step 230, training accuracy 0.965
# step 240, training accuracy 0.995
# step 250, training accuracy 0.995
# step 260, training accuracy 0.975
# step 270, training accuracy 0.985
# step 280, training accuracy 1
# step 290, training accuracy 0.99
# step 0, training accuracy 0.985
# step 10, training accuracy 0.995
# step 20, training accuracy 0.985
# step 30, training accuracy 0.99
# step 40, training accuracy 0.995
# step 50, training accuracy 0.97
# step 60, training accuracy 0.975
# step 70, training accuracy 0.995
# step 80, training accuracy 0.98
# step 90, training accuracy 0.99
# step 100, training accuracy 0.98
# step 110, training accuracy 0.98
# step 120, training accuracy 0.995
# step 130, training accuracy 0.995
# step 140, training accuracy 0.99
# step 150, training accuracy 0.985
# step 160, training accuracy 0.98
# step 170, training accuracy 0.985
# step 180, training accuracy 0.955
# step 190, training accuracy 0.995
# step 200, training accuracy 0.995
# step 210, training accuracy 0.99
# step 220, training accuracy 0.99
# step 230, training accuracy 0.975
# step 240, training accuracy 0.995
# step 250, training accuracy 0.995
# step 260, training accuracy 0.965
# step 270, training accuracy 0.98
# step 280, training accuracy 0.995
# step 290, training accuracy 0.99
# step 0, training accuracy 0.985
# step 10, training accuracy 0.995
# step 20, training accuracy 0.99
# step 30, training accuracy 0.99
# step 40, training accuracy 0.995
# step 50, training accuracy 0.97
# step 60, training accuracy 0.995
# step 70, training accuracy 0.995
# step 80, training accuracy 0.985
# step 90, training accuracy 0.985
# step 100, training accuracy 0.98
# step 110, training accuracy 0.995
# step 120, training accuracy 0.995
# step 130, training accuracy 0.995
# step 140, training accuracy 0.995
# step 150, training accuracy 0.99
# step 160, training accuracy 0.985
# step 170, training accuracy 0.99
# step 180, training accuracy 0.965
# step 190, training accuracy 1
# step 200, training accuracy 0.995
# step 210, training accuracy 0.99
# step 220, training accuracy 0.99
# step 230, training accuracy 0.975
# step 240, training accuracy 0.99
# step 250, training accuracy 0.995
# step 260, training accuracy 0.975
# step 270, training accuracy 0.98
# step 280, training accuracy 1
# step 290, training accuracy 0.99
# step 0, training accuracy 0.985
# step 10, training accuracy 0.99
# step 20, training accuracy 0.99
# step 30, training accuracy 0.99
# step 40, training accuracy 0.995
# step 50, training accuracy 0.965
# step 60, training accuracy 0.985
# step 70, training accuracy 0.985
# step 80, training accuracy 0.985
# step 90, training accuracy 0.985
# step 100, training accuracy 0.995
# step 110, training accuracy 0.985
# step 120, training accuracy 0.995
# step 130, training accuracy 0.995
# step 140, training accuracy 0.995
# step 150, training accuracy 0.975
# step 160, training accuracy 0.97
# step 170, training accuracy 0.985
# step 180, training accuracy 0.97
# step 190, training accuracy 0.995
# step 200, training accuracy 1
# step 210, training accuracy 0.99
# step 220, training accuracy 0.99
# step 230, training accuracy 0.98
# step 240, training accuracy 0.995
# step 250, training accuracy 0.995
# step 260, training accuracy 0.97
# step 270, training accuracy 0.985
# step 280, training accuracy 1
# step 290, training accuracy 0.99
# step 0, training accuracy 0.99
# step 10, training accuracy 0.99
# step 20, training accuracy 0.985
# step 30, training accuracy 0.99
# step 40, training accuracy 0.995
# step 50, training accuracy 0.965
# step 60, training accuracy 0.985
# step 70, training accuracy 0.995
# step 80, training accuracy 0.995
# step 90, training accuracy 0.99
# step 100, training accuracy 0.99
# step 110, training accuracy 0.975
# step 120, training accuracy 0.995
# step 130, training accuracy 0.995
# step 140, training accuracy 0.995
# step 150, training accuracy 0.985
# step 160, training accuracy 0.98
# step 170, training accuracy 0.99
# step 180, training accuracy 0.97
# step 190, training accuracy 0.985
# step 200, training accuracy 0.995
# step 210, training accuracy 0.99
# step 220, training accuracy 0.985
# step 230, training accuracy 0.975
# step 240, training accuracy 0.995
# step 250, training accuracy 0.995
# step 260, training accuracy 0.97
# step 270, training accuracy 0.985
# step 280, training accuracy 1
# step 290, training accuracy 0.985
# step 0, training accuracy 0.985
# step 10, training accuracy 0.995
# step 20, training accuracy 0.995
# step 30, training accuracy 0.99
# step 40, training accuracy 0.995
# step 50, training accuracy 0.975
# step 60, training accuracy 0.995
# step 70, training accuracy 0.99
# step 80, training accuracy 0.975
# step 90, training accuracy 0.995
# step 100, training accuracy 0.99
# step 110, training accuracy 0.985
# step 120, training accuracy 0.995
# step 130, training accuracy 0.995
# step 140, training accuracy 0.995
# step 150, training accuracy 0.995
# step 160, training accuracy 0.99
# step 170, training accuracy 0.985
# step 180, training accuracy 0.97
# step 190, training accuracy 1
# step 200, training accuracy 1
# step 210, training accuracy 0.98
# step 220, training accuracy 0.985
# step 230, training accuracy 0.965
# step 240, training accuracy 0.995
# step 250, training accuracy 0.995
# step 260, training accuracy 0.98
# step 270, training accuracy 0.985
# step 280, training accuracy 1
# step 290, training accuracy 0.985
# step 0, training accuracy 0.99
# step 10, training accuracy 0.995
# step 20, training accuracy 0.985
# step 30, training accuracy 0.99
# step 40, training accuracy 0.995
# step 50, training accuracy 0.975
# step 60, training accuracy 0.995
# step 70, training accuracy 0.995
# step 80, training accuracy 0.975
# step 90, training accuracy 0.995
# step 100, training accuracy 0.985
# step 110, training accuracy 0.975
# step 120, training accuracy 0.995
# step 130, training accuracy 0.995
# step 140, training accuracy 0.995
# step 150, training accuracy 0.99
# step 160, training accuracy 0.99
# step 170, training accuracy 0.99
# step 180, training accuracy 0.97
# step 190, training accuracy 0.99
# step 200, training accuracy 0.995
# step 210, training accuracy 0.995
# step 220, training accuracy 0.98
# step 230, training accuracy 0.975
# step 240, training accuracy 0.99
# step 250, training accuracy 0.995
# step 260, training accuracy 0.965
# step 270, training accuracy 0.985
# step 280, training accuracy 1
# step 290, training accuracy 0.99
# step 0, training accuracy 0.985
# step 10, training accuracy 0.995
# step 20, training accuracy 0.99
# step 30, training accuracy 0.99
# step 40, training accuracy 0.99
# step 50, training accuracy 0.98
# step 60, training accuracy 0.98
# step 70, training accuracy 0.995
# step 80, training accuracy 0.985
# step 90, training accuracy 0.995
# step 100, training accuracy 0.985
# step 110, training accuracy 0.985
# step 120, training accuracy 0.995
# ...
# step 290, training accuracy 0.99
# step 0, training accuracy 0.995
# step 10, training accuracy 1
# step 20, training accuracy 1
# step 30, training accuracy 0.995
# step 40, training accuracy 1
# step 50, training accuracy 1
# step 60, training accuracy 0.995
# step 70, training accuracy 1
# step 80, training accuracy 0.995
# step 90, training accuracy 1
# step 100, training accuracy 1
# step 110, training accuracy 1
# step 120, training accuracy 1
# step 130, training accuracy 1
# step 140, training accuracy 0.995
# step 150, training accuracy 1
# step 160, training accuracy 0.995
# step 170, training accuracy 1
# step 180, training accuracy 0.99
# step 190, training accuracy 1
# step 200, training accuracy 1
# step 210, training accuracy 1
# step 220, training accuracy 0.99
# step 230, training accuracy 0.985
# step 240, training accuracy 0.995
# step 250, training accuracy 1
# step 260, training accuracy 1
# step 270, training accuracy 0.995
# step 280, training accuracy 0.995
# step 290, training accuracy 0.99
# step 0, training accuracy 0.995
# step 10, training accuracy 1
# step 20, training accuracy 1
# step 30, training accuracy 0.995
# step 40, training accuracy 1
# step 50, training accuracy 1
# step 60, training accuracy 0.995
# step 70, training accuracy 1
# step 80, training accuracy 0.995
# step 90, training accuracy 1
# step 100, training accuracy 1
# step 110, training accuracy 1
# step 120, training accuracy 1
# step 130, training accuracy 1
# step 140, training accuracy 0.995
# step 150, training accuracy 1
# step 160, training accuracy 0.995
# step 170, training accuracy 1
# step 180, training accuracy 0.99
# step 190, training accuracy 1
# step 200, training accuracy 1
# step 210, training accuracy 1
# step 220, training accuracy 0.99
# step 230, training accuracy 0.985
# step 240, training accuracy 0.995
# step 250, training accuracy 1
# step 260, training accuracy 1
# step 270, training accuracy 0.995
# step 280, training accuracy 0.995
# step 290, training accuracy 0.99
# step 0, training accuracy 0.995
# step 10, training accuracy 1
# step 20, training accuracy 1
# step 30, training accuracy 0.995
# step 40, training accuracy 1
# step 50, training accuracy 1
# step 60, training accuracy 0.995
# step 70, training accuracy 1
# step 80, training accuracy 0.995
# step 90, training accuracy 1
# step 100, training accuracy 1
# step 110, training accuracy 1
# step 120, training accuracy 1
# step 130, training accuracy 1
# step 140, training accuracy 0.995
# step 150, training accuracy 1
# step 160, training accuracy 0.995
# step 170, training accuracy 1
# step 180, training accuracy 0.99
# step 190, training accuracy 1
# step 200, training accuracy 1
# step 210, training accuracy 1
# step 220, training accuracy 0.99
# step 230, training accuracy 0.985
# step 240, training accuracy 0.995
# step 250, training accuracy 1
# step 260, training accuracy 1
# step 270, training accuracy 0.995
# step 280, training accuracy 0.995
# step 290, training accuracy 0.99
# step 0, training accuracy 0.995
# step 10, training accuracy 1
# step 20, training accuracy 1
# step 30, training accuracy 0.995
# step 40, training accuracy 1
# step 50, training accuracy 1
# step 60, training accuracy 0.995
# step 70, training accuracy 1
# step 80, training accuracy 0.995
# step 90, training accuracy 1
# step 100, training accuracy 1
# step 110, training accuracy 1
# step 120, training accuracy 1
# step 130, training accuracy 1
# step 140, training accuracy 0.995
# step 150, training accuracy 1
# step 160, training accuracy 0.995
# step 170, training accuracy 1
# step 180, training accuracy 0.99
# step 190, training accuracy 1
# step 200, training accuracy 1
# step 210, training accuracy 1
# step 220, training accuracy 0.99
# step 230, training accuracy 0.985
# step 240, training accuracy 0.995
# step 250, training accuracy 1
# step 260, training accuracy 1
# step 270, training accuracy 0.995
# step 280, training accuracy 0.995
# step 290, training accuracy 0.99
# step 0, training accuracy 0.995
# step 10, training accuracy 1
# step 20, training accuracy 1
# step 30, training accuracy 0.995
# step 40, training accuracy 1
# step 50, training accuracy 1
# step 60, training accuracy 0.995
# step 70, training accuracy 1
# step 80, training accuracy 0.995
# step 90, training accuracy 1
# step 100, training accuracy 1
# step 110, training accuracy 1
# step 120, training accuracy 1
# step 130, training accuracy 1
# step 140, training accuracy 0.995
# step 150, training accuracy 1
# step 160, training accuracy 0.995
# step 170, training accuracy 1
# step 180, training accuracy 0.99
# step 190, training accuracy 1
# step 200, training accuracy 1
# step 210, training accuracy 1
# step 220, training accuracy 0.99
# step 230, training accuracy 0.985
# step 240, training accuracy 0.995
# step 250, training accuracy 1
# step 260, training accuracy 1
# step 270, training accuracy 0.995
# step 280, training accuracy 0.995
# step 290, training accuracy 0.99
# step 0, training accuracy 0.995
# step 10, training accuracy 1
# step 20, training accuracy 1
# step 30, training accuracy 0.995
# step 40, training accuracy 1
# step 50, training accuracy 1
# step 60, training accuracy 0.995
# step 70, training accuracy 1
# step 80, training accuracy 0.995
# step 90, training accuracy 1
# step 100, training accuracy 1
# step 110, training accuracy 1
# step 120, training accuracy 1
# step 130, training accuracy 1
# step 140, training accuracy 0.995
# step 150, training accuracy 1
# step 160, training accuracy 0.995
# step 170, training accuracy 1
# step 180, training accuracy 0.99
# step 190, training accuracy 1
# step 200, training accuracy 1
# step 210, training accuracy 1
# step 220, training accuracy 0.99
# step 230, training accuracy 0.985
# step 240, training accuracy 0.995
# step 250, training accuracy 1
# step 260, training accuracy 1
# step 270, training accuracy 0.995
# step 280, training accuracy 0.995
# step 290, training accuracy 0.99
# step 0, training accuracy 0.995
# step 10, training accuracy 1
# step 20, training accuracy 1
# step 30, training accuracy 0.995
# step 40, training accuracy 1
# step 50, training accuracy 1
# step 60, training accuracy 0.995
# step 70, training accuracy 1
# step 80, training accuracy 0.995
# step 90, training accuracy 1
# step 100, training accuracy 1
# step 110, training accuracy 1
# step 120, training accuracy 1
# step 130, training accuracy 1
# step 140, training accuracy 0.995
# step 150, training accuracy 1
# step 160, training accuracy 0.995
# step 170, training accuracy 1
# step 180, training accuracy 0.99
# step 190, training accuracy 1
# step 200, training accuracy 1
# step 210, training accuracy 1
# step 220, training accuracy 0.99
# step 230, training accuracy 0.985
# step 240, training accuracy 0.995
# step 250, training accuracy 1
# step 260, training accuracy 1
# step 270, training accuracy 0.995
# step 280, training accuracy 0.995
# step 290, training accuracy 0.99
# step 0, training accuracy 0.995
# step 10, training accuracy 1
# step 20, training accuracy 1
# step 30, training accuracy 0.995
# step 40, training accuracy 1
# step 50, training accuracy 1
# step 60, training accuracy 0.995
# step 70, training accuracy 1
# step 80, training accuracy 0.995
# step 90, training accuracy 1
# step 100, training accuracy 1
# step 110, training accuracy 1
# step 120, training accuracy 1
# step 130, training accuracy 1
# step 140, training accuracy 0.995
# step 150, training accuracy 1
# step 160, training accuracy 0.995
# step 170, training accuracy 1
# step 180, training accuracy 0.99
# step 190, training accuracy 1
# step 200, training accuracy 1
# step 210, training accuracy 1
# step 220, training accuracy 0.99
# step 230, training accuracy 0.985
# step 240, training accuracy 0.995
# step 250, training accuracy 1
# step 260, training accuracy 1
# step 270, training accuracy 0.995
# step 280, training accuracy 0.995
# step 290, training accuracy 0.99
# step 0, training accuracy 0.995
# step 10, training accuracy 1
# step 20, training accuracy 1
# step 30, training accuracy 0.995
# step 40, training accuracy 1
# step 50, training accuracy 1
# step 60, training accuracy 0.995
# step 70, training accuracy 1
# step 80, training accuracy 0.995
# step 90, training accuracy 1
# step 100, training accuracy 1
# step 110, training accuracy 1
# step 120, training accuracy 1
# step 130, training accuracy 1
# step 140, training accuracy 0.995
# step 150, training accuracy 1
# step 160, training accuracy 0.995
# step 170, training accuracy 1
# step 180, training accuracy 0.99
# step 190, training accuracy 1
# step 200, training accuracy 1
# step 210, training accuracy 1
# step 220, training accuracy 0.99
# step 230, training accuracy 0.985
# step 240, training accuracy 0.995
# step 250, training accuracy 1
# step 260, training accuracy 1
# step 270, training accuracy 0.995
# step 280, training accuracy 0.995
# step 290, training accuracy 0.99
# step 0, training accuracy 0.995
# step 10, training accuracy 1
# step 20, training accuracy 1
# step 30, training accuracy 0.995
# step 40, training accuracy 1
# step 50, training accuracy 1
# step 60, training accuracy 0.995
# step 70, training accuracy 1
# step 80, training accuracy 0.995
# step 90, training accuracy 1
# step 100, training accuracy 1
# step 110, training accuracy 1
# step 120, training accuracy 1
# step 130, training accuracy 1
# step 140, training accuracy 0.995
# step 150, training accuracy 1
# step 160, training accuracy 0.995
# step 170, training accuracy 1
# step 180, training accuracy 0.99
# step 190, training accuracy 1
# step 200, training accuracy 1
# step 210, training accuracy 1
# step 220, training accuracy 0.99
# step 230, training accuracy 0.985
# step 240, training accuracy 0.995
# step 250, training accuracy 1
# step 260, training accuracy 1
# step 270, training accuracy 0.995
# step 280, training accuracy 0.995
# step 290, training accuracy 0.99
# step 0, training accuracy 0.995
# step 10, training accuracy 1
# step 20, training accuracy 1
# step 30, training accuracy 0.995
# step 40, training accuracy 1
# step 50, training accuracy 1
# step 60, training accuracy 0.995
# step 70, training accuracy 1
# step 80, training accuracy 0.995
# step 90, training accuracy 1
# step 100, training accuracy 1
# step 110, training accuracy 1
# step 120, training accuracy 1
# step 130, training accuracy 1
# step 140, training accuracy 0.995
# step 150, training accuracy 1
# step 160, training accuracy 0.995
# step 170, training accuracy 1
# step 180, training accuracy 0.99
# step 190, training accuracy 1
# step 200, training accuracy 1
# step 210, training accuracy 1
# step 220, training accuracy 0.99
# step 230, training accuracy 0.985
# step 240, training accuracy 0.995
# step 250, training accuracy 1
# step 260, training accuracy 1
# step 270, training accuracy 0.995
# step 280, training accuracy 0.995
# step 290, training accuracy 0.99
# step 0, training accuracy 0.995
# step 10, training accuracy 1
# step 20, training accuracy 1
# step 30, training accuracy 0.995
# step 40, training accuracy 1
# step 50, training accuracy 1
# step 60, training accuracy 0.995
# step 70, training accuracy 1
# step 80, training accuracy 0.995
# step 90, training accuracy 1
# step 100, training accuracy 1
# step 110, training accuracy 1
# step 120, training accuracy 1
# step 130, training accuracy 1
# step 140, training accuracy 0.995
# step 150, training accuracy 1
# step 160, training accuracy 0.995
# step 170, training accuracy 1
# step 180, training accuracy 0.99
# step 190, training accuracy 1
# step 200, training accuracy 1
# step 210, training accuracy 1
# step 220, training accuracy 0.99
# step 230, training accuracy 0.985
# step 240, training accuracy 0.995
# step 250, training accuracy 1
# step 260, training accuracy 1
# step 270, training accuracy 0.995
# step 280, training accuracy 0.995
# step 290, training accuracy 0.99
# step 0, training accuracy 0.995
# step 10, training accuracy 1
# step 20, training accuracy 1
# step 30, training accuracy 0.995
# step 40, training accuracy 1
# step 50, training accuracy 1
# step 60, training accuracy 0.995
# step 70, training accuracy 1
# step 80, training accuracy 0.995
# step 90, training accuracy 1
# step 100, training accuracy 1
# step 110, training accuracy 1
# step 120, training accuracy 1
# step 130, training accuracy 1
# step 140, training accuracy 0.995
# step 150, training accuracy 1
# step 160, training accuracy 0.995
# step 170, training accuracy 1
# step 180, training accuracy 0.99
# step 190, training accuracy 1
# step 200, training accuracy 1
# step 210, training accuracy 1
# step 220, training accuracy 0.99
# step 230, training accuracy 0.985
# step 240, training accuracy 0.995
# step 250, training accuracy 1
# step 260, training accuracy 1
# step 270, training accuracy 0.995
# step 280, training accuracy 0.995
# step 290, training accuracy 0.99
# step 0, training accuracy 0.995
# step 10, training accuracy 1
# step 20, training accuracy 1
# step 30, training accuracy 0.995
# step 40, training accuracy 1
# step 50, training accuracy 1
# step 60, training accuracy 0.995
# step 70, training accuracy 1
# step 80, training accuracy 0.995
# step 90, training accuracy 1
# step 100, training accuracy 1
# step 110, training accuracy 1
# step 120, training accuracy 1
# step 130, training accuracy 1
# step 140, training accuracy 0.995
# step 150, training accuracy 1
# step 160, training accuracy 0.995
# step 170, training accuracy 1
# step 180, training accuracy 0.99
# step 190, training accuracy 1
# step 200, training accuracy 1
# step 210, training accuracy 1
# step 220, training accuracy 0.99
# step 230, training accuracy 0.985
# step 240, training accuracy 0.995
# step 250, training accuracy 1
# step 260, training accuracy 1
# step 270, training accuracy 0.995
# step 280, training accuracy 0.995
# step 290, training accuracy 0.99
# step 0, training accuracy 0.995
# step 10, training accuracy 1
# step 20, training accuracy 1
# step 30, training accuracy 0.995
# step 40, training accuracy 1
# step 50, training accuracy 1
# step 60, training accuracy 0.995
# step 70, training accuracy 1
# step 80, training accuracy 0.995
# step 90, training accuracy 1
# step 100, training accuracy 1
# step 110, training accuracy 1
# step 120, training accuracy 1
# step 130, training accuracy 1
# step 140, training accuracy 0.995
# step 150, training accuracy 1
# step 160, training accuracy 0.995
# step 170, training accuracy 1
# step 180, training accuracy 0.99
# step 190, training accuracy 1
# step 200, training accuracy 1
# step 210, training accuracy 1
# step 220, training accuracy 0.99
# step 230, training accuracy 0.985
# step 240, training accuracy 0.995
# step 250, training accuracy 1
# step 260, training accuracy 1
# step 270, training accuracy 0.995
# step 280, training accuracy 0.995
# step 290, training accuracy 0.99
# step 0, training accuracy 0.995
# step 10, training accuracy 1
# step 20, training accuracy 1
# step 30, training accuracy 0.995
# step 40, training accuracy 1
# step 50, training accuracy 1
# step 60, training accuracy 0.995
# step 70, training accuracy 1
# step 80, training accuracy 0.995
# step 90, training accuracy 1
# step 100, training accuracy 1
# step 110, training accuracy 1
# step 120, training accuracy 1
# step 130, training accuracy 1
# step 140, training accuracy 0.995
# step 150, training accuracy 1
# step 160, training accuracy 0.995
# step 170, training accuracy 1
# step 180, training accuracy 0.99
# step 190, training accuracy 1
# step 200, training accuracy 1
# step 210, training accuracy 1
# step 220, training accuracy 0.99
# step 230, training accuracy 0.985
# step 240, training accuracy 0.995
# step 250, training accuracy 1
# step 260, training accuracy 1
# step 270, training accuracy 0.995
# step 280, training accuracy 0.995
# step 290, training accuracy 0.99
# step 0, training accuracy 0.995
# step 10, training accuracy 1
# step 20, training accuracy 1
# step 30, training accuracy 0.995
# step 40, training accuracy 1
# step 50, training accuracy 1
# step 60, training accuracy 0.995
# step 70, training accuracy 1
# step 80, training accuracy 0.995
# step 90, training accuracy 1
# step 100, training accuracy 1
# step 110, training accuracy 1
# step 120, training accuracy 1
# step 130, training accuracy 1
# step 140, training accuracy 0.995
# step 150, training accuracy 1
# step 160, training accuracy 0.995
# step 170, training accuracy 1
# step 180, training accuracy 0.99
# step 190, training accuracy 1
# step 200, training accuracy 1
# step 210, training accuracy 1
# step 220, training accuracy 0.99
# step 230, training accuracy 0.985
# step 240, training accuracy 0.995
# step 250, training accuracy 1
# step 260, training accuracy 1
# step 270, training accuracy 0.995
# step 280, training accuracy 0.995
# step 290, training accuracy 0.99

# %%
test = pd.read_csv('/content/gdrive/My Drive/DeepLearning/test_july.csv')

# %%
test_X = test.drop(['index'],axis=1)
test_X = test_X/255

# %%
test_Y = tf.argmax(y_conv,1)

# %%
output = test_Y.eval(session=sess,feed_dict={x:test_X})

# %%
submit = pd.read_csv('/content/gdrive/My Drive/DeepLearning/sample_submission.csv')

# %%
submit['label']=output

# %%
submit.to_csv('sample_submission.csv',index=None)
